# %% [markdown]
# <h1 style = "font-family: Comic Sans MS;background-color:#C70039"> BIRDS </h1>
#
# **Can you imagine life without birds?! They are not just creatures that beautify our planet but they also contribute to the balance and the operation of our ecosystem. As humans, we are responsible for their endangerment and preservation.**
#
# ***Birds are wherever we are. They are our companions. Birds are mediators between heaven and earth.
# <br>—Terry Tempest Williams***
#
# ![34-min.jpg](attachment:a18640ab-d85a-4bc9-a24a-e8c404a6f7f9.jpg)
#
# **Few of the many benefits of birds are as follows.**
# <ol>
#     <b><li>Pest Control</li></b>
#     <b><li>Pollination and Seed Dispersal </li><b>
#     <b><li>Scavenging </li></b>
#     <b><li>Nutrient Cyling </li></b>
#     <b><li>Soil Reformation </li></b>
#     <b><li>Nature's Clean-up Crew </li></b>
#     <b><li>Transform Landspaces </li></b>
#     <b><li>Keep Coral Reefs Alive </li></b>
# </ol>

# %% [markdown]
# <h1 style = "font-family: Comic Sans MS;background-color:#FFC305"> ABOUT THE DATASET </h1>
#
# **The State of India’s Birds report is the first comprehensive assessment of the distribution range, trends in abundance, and conservation status for most of the bird species that regularly occur in India. With their ubiquity and ecological importance, birds are excellent indicators of the state of our natural world and are potent cultural symbols of nature. This national-level assessment of birds is a significant step forward in the monitoring and conservation of India’s rich and varied biodiversity.**
#
# ![35-min.jpg](attachment:ce5b1173-45fd-4faa-a60a-ad2592ec8c47.jpg)
#
# **The State of India’s Birds report was created to assess the conservation status of the majority of species that regularly occur in the country. Worldwide, common and widespread species are declining; but in India, lack of information has meant that conservation attention has been focussed on only a few species (usually large, charismatic and threatened).**
#
# **The report fills this gap by using over 10 million observations uploaded to the eBird platform by more than 15,500 birdwatchers to evaluate the distribution range size of 867 Indian birds, and their trends in abundance in both the long term (over 25+ years) and currently (past 5 years). Using these three measures, plus information from the IUCN Red List of global threat status, this report places Indian species into Low, Moderate and High categories of Conservation Concern for India. A large number of species that are thought to be common and widespread find themselves as of High Conservation Concern.**
#
# ![36-min.jpg](attachment:c1e306ba-ee14-4369-9c46-0f4eaf2a0e94.jpg)
#
#
# <br><br>
# #### **LINKS!**
# **DATASET: https://www.kaggle.com/usharengaraju/state-of-indias-birds-2020** <BR>
# **SOURCE: https://www.stateofindiasbirds.in/#soib_report**

# %% [markdown]
# <h1 style = "font-family: Comic Sans MS;background-color:#77DD77"> CONTENTS </h1>
#
# 1. [INSTALL PACKAGES](#sec1) <br>
# 2. [IMPORT LIBRARIES](#sec2) <br>
# 3. [DATA LOADING](#sec3) <br>
# 4. [METADATA DESCRIPTION](#sec4) <br>
# 5. [PRELIMINARY ANALYSIS](#sec5) <br>
# 6. [MISSING VALUES](#sec6) <br>
# 7. [CORRELATION BETWEEN NUMERICAL FEATURES](#sec7) <br>
# 8. [DISTRIBUTION OF NUMERICAL FEATURES](#sec8) <br>
# 9. [CONFIDENCE INTERVALS](#sec9) <br>
# 10. [IUCN STATUS](#sec10) <br>
# 11. [WLPA SCHEDULE FOR EACH IUCN STATUS](#sec11) <br>
# 12. [CURRENT STATUS FOR EACH IUCN STATUS](#sec12) <br>
# 13. [MIGRATORY STATUS FOR EACH CURRENT STATUS](#sec13) <br>
# 14. [DISTRIBUTION STATUS FOR EACH LONG TERM STATUS](#sec14) <br>
# 15. [LONG TERM STATUS Vs CURRENT STATUS](#sec15) <br>
# 16. [10 MOST DECREASING IN ABUNDANCE BIRD SPECIES IN THE LAST 5 YEARS](#sec16) <br>
# 17. [10 MOST INCREASING IN ABUNDANCE BIRD SPECIES IN THE LAST 5 YEARS](#sec17) <br>
# 18. [10 MOST DECREASING IN ABUNDANCE BIRD SPECIES IN 25+ YEARS](#sec18) <br>
# 19. [10 MOST INCREASING IN ABUNDANCE BIRD SPECIES IN 25+ YEARS](#sec19) <br>
# 20. [10 MOST DECREASING IN DISTRIBUTION BIRD SPECIES IN THE LAST 5 YEARS](#sec20) <br>
# 21. [10 MOST INCREASING IN ABUNDANCE BIRD SPECIES IN THE LAST 5 YEARS](#sec21) <br>
# 22. [HOW DOES CURRENT ANNUAL CHANGE RELATE TO THE CURRENT STATUS AND THE IUCN STATUS?](#sec22) <br>
# 23. [HOW DO ALL THE TRENDS RELATE TO THE DISTRIBUTION STATUS FOR LEAST CONCERNING SPECIES?](#sec23) <br>
# 24. [HOW DO ALL THE TRENDS RELATE TO THE DISTRIBUTION STATUS FOR CONCERNING SPECIES?](#sec24) <br>
# 25. [HOW DOES LONG TERM TREND AND DISTRIBUTION STATUS RELATE TO EACHOTHER?](#sec25) <br>
# 26. [HOW DO THEY RELATE TO THE LONG TERM STATUS AND STATUS OF CONSERVATION CONCERN FOR LEAST CONCERNING SPECIES?](#sec26) <br>
# 27. [HOW DO THEY RELATE TO THE LONG TERM STATUS AND STATUS OF CONSERVATION CONCERN FOR CONCERNING SPECIES?](#sec27) <br>
# 28. [CONCLUSION](#sec28) <br>

# %% [markdown]
# <h2 id = 'sec1' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> INSTALL PACKAGES </h2>

# %%
# !pip install openpyxl
# Out:
# ...
#      |████████████████████████████████| 243 kB 898 kB/s
# ...
# done
#   Created wheel for et-xmlfile: filename=et_xmlfile-1.0.1-py3-none-any.whl size=8913 sha256=2911e6e36c0ea919098491504103d5c7a4e6f1242524c1048be1ef91954f82c5
#   Stored in directory: /root/.cache/pip/wheels/e2/bd/55/048b4fd505716c4c298f42ee02dffd9496bb6d212b266c7f31
# Successfully built et-xmlfile
# ...

# %% [markdown]
# <h2 id='sec2' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> IMPORT LIBRARIES </h2>

# %%
from IPython.display import Image
import pandas as pd
pd.options.display.max_colwidth = 180
import numpy as np
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go
import plotly.figure_factory as ff
from plotly.subplots import make_subplots
from statsmodels.graphics.mosaicplot import mosaic
import matplotlib.pyplot as plt
# %matplotlib inline
from colorama import Fore
r = Fore.RED
g = Fore.GREEN
y = Fore.YELLOW
b = Fore.BLUE
m = Fore.MAGENTA
c = Fore.CYAN

# %% [markdown]
# <h2 id='sec3' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> DATA LOADING </h2>

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/state-of-indias-birds-2020/State of Indias Birds - Essentials.xlsx

# %%
data = pd.read_excel('../input/state-of-indias-birds-2020/State of Indias Birds - Essentials.xlsx', sheet_name = 'Information', engine = 'openpyxl')
data.head()
# Out:
#    Serial Number Common Name (India Checklist)  \
# 0              1        Fulvous Whistling Duck
# 1              2         Lesser Whistling Duck
# 2              3              Bar-headed Goose
# 3              4                 Greylag Goose
# 4              5                     Comb Duck
#
#   Scientific Name (India Checklist)    IUCN Status WLPA Schedule  \
# 0               Dendrocygna bicolor  Least Concern    Schedule-I
# 1              Dendrocygna javanica  Least Concern   Schedule-IV
# 2                     Anser indicus  Least Concern   Schedule-IV
# 3                       Anser anser  Least Concern   Schedule-IV
# 4            Sarkidiornis melanotos  Least Concern   Schedule-IV
#
#   Analysed Long-term Analysed Current  Long-term Trend (%)  \
# 0                NaN                X                  NaN
# 1                  X                X             4.607645
# 2                  X                X           -13.399940
# ...

# %% [markdown]
# <h2 id='sec4' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> METADATA DESCRIPTION </h2>

# %%
meta = pd.read_excel('../input/state-of-indias-birds-2020/State of Indias Birds - Essentials.xlsx', sheet_name = 'Key', header = None, engine = 'openpyxl').iloc[2 : -2, :]
meta.columns = ['Key Name', 'Description']
meta.index = [i for i in range (1, 20)]
meta
# Out:
#                                                 Key Name  \
# 1                                          Serial Number
# 2                          Common Name (India Checklist)
# 3                      Scientific Name (India Checklist)
# 4                                            IUCN Status
# 5                                          WLPA Schedule
# 6                                     Analysed Long-term
# 7                                       Analysed Current
# 8                                    Long-term Trend (%)
# 9                                 Long-term Trend CI (%)
# 10                             Current Annual Change (%)
# 11                          Current Annual Change CI (%)
# 12     Distribution Range Size (units of 10,000 sq. km.)
# 13  Distribution Range Size CI (units of 10,000 sq. km.)
# 14                                      Long-term Status
# 15                                        Current Status
# ...

# %% [markdown]
# <h2 id='sec5' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> PRELIMINARY ANALYSIS </h2>

# %%
print(f"{r}Data Shape => {y}{data.shape}")
# Out:
# Data Shape => (867, 19)

# %%
print(f"{m}Information Data Types \n\n {c}{data.dtypes}")
# Out:
# Information Data Types
#
#  Serial Number                                             int64
# Common Name (India Checklist)                            object
# Scientific Name (India Checklist)                        object
# IUCN Status                                              object
# WLPA Schedule                                            object
# Analysed Long-term                                       object
# Analysed Current                                         object
# Long-term Trend (%)                                     float64
# Long-term Trend CI (%)                                  float64
# Current Annual Change (%)                               float64
# Current Annual Change CI (%)                            float64
# Distribution Range Size (units of 10,000 sq. km.)       float64
# Distribution Range Size CI (units of 10,000 sq. km.)    float64
# Long Term Status                                         object
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 867 entries, 0 to 866
# Data columns (total 19 columns):
#  #   Column                                                Non-Null Count  Dtype
# ---  ------                                                --------------  -----
#  0   Serial Number                                         867 non-null    int64
#  1   Common Name (India Checklist)                         867 non-null    object
#  2   Scientific Name (India Checklist)                     867 non-null    object
#  3   IUCN Status                                           867 non-null    object
#  4   WLPA Schedule                                         867 non-null    object
#  5   Analysed Long-term                                    485 non-null    object
#  6   Analysed Current                                      675 non-null    object
#  7   Long-term Trend (%)                                   487 non-null    float64
# ...

# %%
data.describe().style.background_gradient(cmap = 'Pastel1')
# Out:
# <style  type="text/css" >
# #T_ec1783d2_9f91_11eb_956c_0242ac130202row0_col0,#T_ec1783d2_9f91_11eb_956c_0242ac130202row0_col1,#T_ec1783d2_9f91_11eb_956c_0242ac130202row0_col2,#T_ec1783d2_9f91_11eb_956c_0242ac130202row0_col3,#T_ec1783d2_9f91_11eb_956c_0242ac130202row0_col4,#T_ec1783d2_9f91_11eb_956c_0242ac130202row0_col5,#T_ec1783d2_9f91_11eb_956c_0242ac130202row0_col6,#T_ec1783d2_9f91_11eb_956c_0242ac130202row7_col0{
#             background-color:  #f2f2f2;
#             color:  #000000;
#         }#T_ec1783d2_9f91_11eb_956c_0242ac130202row1_col0,#T_ec1783d2_9f91_11eb_956c_0242ac130202row5_col0,#T_ec1783d2_9f91_11eb_956c_0242ac130202row7_col1{
#             background-color:  #fed9a6;
#             color:  #000000;
#         }#T_ec1783d2_9f91_11eb_956c_0242ac130202row1_col1,#T_ec1783d2_9f91_11eb_956c_0242ac130202row5_col1,#T_ec1783d2_9f91_11eb_956c_0242ac130202row6_col1{
#             background-color:  #b3cde3;
#             color:  #000000;
# ...

# %%
data[[i for i in data.columns if data[i].dtype == 'object']].describe()
# Out:
#        Common Name (India Checklist) Scientific Name (India Checklist)  \
# count                            867                               867
# unique                           867                               867
# top        Tickell's Blue Flycatcher                   Sitta leucopsis
# freq                               1                                 1
#
#           IUCN Status WLPA Schedule Analysed Long-term Analysed Current  \
# count             867           867                485              675
# unique              5             3                  1                1
# top     Least Concern   Schedule-IV                  X                X
# freq              736           786                485              675
#
#        Long Term Status Current Status Distribution Status  \
# count               862            862                 862
# unique                7              7                   6
# top      Data Deficient      Uncertain            Moderate
# ...

# %% [markdown]
# <h2 id='sec6' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> MISSING VALUES </h2>

# %%
data.isna().head()
# Out:
#    Serial Number  Common Name (India Checklist)  \
# 0          False                          False
# 1          False                          False
# 2          False                          False
# 3          False                          False
# 4          False                          False
#
#    Scientific Name (India Checklist)  IUCN Status  WLPA Schedule  \
# 0                              False        False          False
# 1                              False        False          False
# 2                              False        False          False
# 3                              False        False          False
# 4                              False        False          False
#
#    Analysed Long-term  Analysed Current  Long-term Trend (%)  \
# 0                True             False                 True
# 1               False             False                False
# 2               False             False                False
# ...

# %%
px.bar(data.isnull().sum(), x = data.isnull().sum().index, y = data.isnull().sum().values / len(data) * 100, title = 'Missing Values in Data', color = data.isnull().sum().values, labels = dict(index = "Attributes", y = "Percentage of Missing Values"))
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
# ...

# %%
df_analyzed = data[data['Analysed Long-term'].isnull() == False]
df_analyzed = df_analyzed[df_analyzed['Analysed Current'].isnull() == False]
print(f"{b}Information Data Types\n\n{g}{df_analyzed.isnull().sum()}")
# Out:
# Information Data Types
#
# Serial Number                                           0
# Common Name (India Checklist)                           0
# Scientific Name (India Checklist)                       0
# IUCN Status                                             0
# WLPA Schedule                                           0
# Analysed Long-term                                      0
# Analysed Current                                        0
# Long-term Trend (%)                                     0
# Long-term Trend CI (%)                                  0
# Current Annual Change (%)                               0
# Current Annual Change CI (%)                            0
# Distribution Range Size (units of 10,000 sq. km.)       0
# Distribution Range Size CI (units of 10,000 sq. km.)    0
# Long Term Status                                        0
# Current Status                                          0
# Distribution Status                                     0
# ...

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>💡 All the missing values in the data imply to the bird species that were not assesed for long term trends or current trends or both (Checked in the code block above). As seen in the bar chart, the missing data accounts to 56%. It wouldn't make sense to impute all of these values. Also, cannot discard these attributes as they are very essential in understanding the underlying distribution and relationships between features in the data. Hence, EDA shall be performed on completely analyzed species of birds. </div>

# %% [markdown]
# <h2 id='sec7' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> CORRELATION BETWEEN NUMERICAL FEATURES </h2>

# %%
matrix = np.triu(df_analyzed.corr().iloc[1 : , 1 : ])
plt.figure(figsize = (8, 8))
fig = sns.heatmap(df_analyzed.corr().iloc[1 : , 1 : ], annot=True, mask=matrix, cmap = "cividis_r")
fig.set(title = 'Correlation between Numerical Features')
plt.show()

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>✔ From the heatmap above, the following insights about the correlation between numerical features can be drawn.
#
# * Relatively Stronger Associations =>
#     1. Current Annual Change (%) and Current Annual Change CI (%)
#     2. Current Annual Change CI (%) and Long-term Trend CI (%)
#     3. Long-term Trend (%) and Distribution Range Size (units of 10,000 sq. km.)
#     4. Long-term Trend (%) and Long-term Trend CI (%)
# </div>

# %% [markdown]
# <h2 id='sec8' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> DISTRIBUTION OF NUMERICAL FEATURES </h2>

# %%
sns.pairplot(df_analyzed.iloc[ : , 1 : ], hue = 'Status of Conservation Concern', diag_kind = "kde", height = 4, palette = 'dark')
plt.show()

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>🎇 This plot helps us comprehend the distrution of data against all pairs of numerical attributes for each status of conservation concern. Species with low status of conservation concern are much higher than the species with low status of conservation concern. Similar behaviours of the heatmap are realized in this graph. </div>

# %% [markdown]
# <h2 id='sec9' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> CONFIDENCE INTERVALS </h2>

# %%
fig = make_subplots(rows = 3, cols = 2)
fig.add_trace(go.Histogram(x = df_analyzed['Current Annual Change CI (%)'], name = 'Current Annual Change CI (%)', nbinsy = 10), 1, 1)
fig.add_trace(go.Histogram(x = df_analyzed['Long-term Trend CI (%)'], name = 'Long-term Trend CI (%)', nbinsy = 10), 2, 1)
fig.add_trace(go.Histogram(x = df_analyzed['Distribution Range Size CI (units of 10,000 sq. km.)'], name = 'Distribution Range Size CI (units of 10,000 sq. km.)', nbinsy = 10), 3, 1)
fig.add_trace(go.Histogram(x = df_analyzed['Current Annual Change (%)'], name = 'Current Annual Change (%)', nbinsy = 10), 1, 2)
fig.add_trace(go.Histogram(x = df_analyzed['Long-term Trend (%)'], name = 'Long-term Trend (%)', nbinsy = 10), 2, 2)
fig.add_trace(go.Histogram(x = df_analyzed['Distribution Range Size (units of 10,000 sq. km.)'], name = 'Distribution Range Size (units of 10,000 sq. km.)', nbinsy = 10), 3, 2)

fig.update_layout(barmode='overlay')
fig.update_traces(opacity=0.75)

fig.show()
# Out:
# <div>                            <div id="13d227f2-b9ac-414e-a94b-c5f98e7094e1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("13d227f2-b9ac-414e-a94b-c5f98e7094e1")) {                    Plotly.newPlot(                        "13d227f2-b9ac-414e-a94b-c5f98e7094e1",                        [{"name": "Current Annual Change CI (%)", "nbinsy": 10, "opacity": 0.75, "type": "histogram", "x": [2.727739793, 38.94695007, 8.853505483, 4.432596981, 11.36083898, 3.158942744, 5.195318715, 5.818148836, 8.119405109, 46.43318578, 2.695449405, 17.80045445, 18.75879961, 12.27310964, 8.082001952, 8.528236833, 18.96233947, 28.20570327, 3.557322358, 4.883762442, 6.831268099, 19.60986484, 4.206338195, 7.849381662, 3.504586328, 6.414148188, 5.484785466, 8.845250761, 8.54
# ...

# %%
df_c = df_analyzed[df_analyzed['Current Annual Change CI (%)'] < 10.0]
df = df_c[df_c['Long-term Trend CI (%)'] < 30.0]

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>🌟 Confidence Interval in Statistics is a range of values where in there is a fair probability that the true value exists. A higher CI indicates that there is a high uncertainity in estimation. Therefore, the lower the CI, the better. By visualizing histograms for the parameters and their respective CIs, a good CI can be choosen. Since the range of values for current annual change and its CI are not that wide, a CI of 10.0 is selected. Long term trend and its CI having a wider range, a CI of 30.0 is choosen. This is done to eliminate instances that are too inaccurate. </div>

# %% [markdown]
# <h2 id='sec10' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> IUCN STATUS </h2>

# %%
px.pie(df, values = df['IUCN Status'].value_counts().values, names = data['IUCN Status'].value_counts().index, title = 'IUCN Status', color_discrete_sequence = px.colors.sequential.Sunset)
# Out:
# <div>                            <div id="5706de7e-437d-4ba8-85f0-686bf9275239" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("5706de7e-437d-4ba8-85f0-686bf9275239")) {                    Plotly.newPlot(                        "5706de7e-437d-4ba8-85f0-686bf9275239",                        [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hovertemplate": "label=%{label}<br>value=%{value}<extra></extra>", "labels": ["Least Concern", "Vulnerable", "Near Threatened", "Endangered", "Critically Endangered"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie", "values": [234, 9, 4, 3, 1]}],                        {"legend": {"tracegroupgap": 0}, "piecolorway": ["rgb(243, 231, 155)", "rgb(250, 196, 132)", "rgb(248, 160, 126)", "rgb(235, 127, 1
# ...

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>🔍 Concerning species (Vulnerable, Near Threatened, Endangered, and Critically Endangered) amount to only 6.8%. On the contrary, least concerning species amount to 93.2%. A few examples from each category are presented below. </div>

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#CBAACB;"> Critically Endangered </h2>
# White-rumped Vulture
#
# ![1-min.jpg](attachment:7df2e53e-b31b-418d-bf9c-7782aa3fa83a.jpg)
#
# Indian Vulture
#
# ![2-min.jpg](attachment:e3207854-d04e-4d63-b50c-b4b5b91ef261.jpg)
#
# Red-headed Vulture
#
# ![3-min.jpg](attachment:8593ba5d-db9c-41f6-8b8f-eaac1370addf.jpg)

# %%
df[df['IUCN Status'] == 'Critically Endangered'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'IUCN Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 242            Red-headed Vulture                  Sarcogyps calvus
# 244          White-rumped Vulture                  Gyps bengalensis
# 245                Indian Vulture                      Gyps indicus
#
#                IUCN Status
# 242  Critically Endangered
# 244  Critically Endangered
# 245  Critically Endangered

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#F3B0C3;"> Endangered </h2>
# Egyptian Vulture
#
# ![4-min.jpg](attachment:bdfacbb5-cca4-427d-9af5-d6fc73ad6a0a.jpg)

# %%
df[df['IUCN Status'] == 'Endangered'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'IUCN Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 238              Egyptian Vulture             Neophron percnopterus
#
#     IUCN Status
# 238  Endangered

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#FFAEA5;"> Near Threatened </h2>
# Red-necked Falcon
#
# ![5-min.jpg](attachment:89ef3b70-50ff-411e-b59b-578691bd71a1.jpg)
#
# River Tern
#
# ![6-min.jpg](attachment:be086829-2ab2-44b8-b937-3da962a8462f.jpg)
#
# Oriental Darter
#
# ![29-min.jpg](attachment:2d663c51-529b-499f-8bf3-d2f1a9a72166.jpg)

# %%
df[df['IUCN Status'] == 'Near Threatened'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'IUCN Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 138              Great Thick-knee             Esacus recurvirostris
# 145                 River Lapwing               Vanellus duvaucelii
# 159               Eurasian Curlew                  Numenius arquata
# 161           Black-tailed Godwit                     Limosa limosa
# 166              Curlew Sandpiper               Calidris ferruginea
# 198                    River Tern                   Sterna aurantia
# 209               Oriental Darter              Anhinga melanogaster
# 237               Bearded Vulture                 Gypaetus barbatus
# 361             Red-necked Falcon                   Falco chicquera
#
#          IUCN Status
# 138  Near Threatened
# 145  Near Threatened
# 159  Near Threatened
# 161  Near Threatened
# 166  Near Threatened
# 198  Near Threatened
# 209  Near Threatened
# 237  Near Threatened
# 361  Near Threatened

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#FFC8A2;"> Vulnerable </h2>
# Tawny Eagle
#
# ![8-min.jpg](attachment:a909d27d-bff6-48f4-9272-4ff2f7b34a3a.jpg)
#
# Woolly-necked Stork
#
# ![30-min.jpg](attachment:c13b76a9-ae46-4382-84ef-4ec12a8283b7.jpg)
#
# Sarus Crane
#
# ![10-min.jpg](attachment:89e7c0cf-8531-408b-ab8a-0775dd15026a.jpg)

# %%
df[df['IUCN Status'] == 'Vulnerable'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'IUCN Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 18                 Common Pochard                     Aythya ferina
# 134                   Sarus Crane                 Antigone antigone
# 204           Woolly-necked Stork                 Ciconia episcopus
# 261                   Tawny Eagle                      Aquila rapax
#
#     IUCN Status
# 18   Vulnerable
# 134  Vulnerable
# 204  Vulnerable
# 261  Vulnerable

# %% [markdown]
# <h2 id='sec11' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> WLPA SCHEDULE FOR EACH IUCN STATUS </h2>

# %%
px.bar(df, x = "IUCN Status", y = "WLPA Schedule", color = "WLPA Schedule", title = "WLPA Schedule", color_discrete_map = {"Schedule-I" : "rgb(33, 75, 99)", "Schedule-IV" : "rgb(177, 127, 38)", "Schedule-V" : "rgb(101, 12, 15)"})
# Out:
# <div>                            <div id="63f2365f-f759-4b2a-8e2c-7841ee6d69d2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("63f2365f-f759-4b2a-8e2c-7841ee6d69d2")) {                    Plotly.newPlot(                        "63f2365f-f759-4b2a-8e2c-7841ee6d69d2",                        [{"alignmentgroup": "True", "hovertemplate": "WLPA Schedule=%{y}<br>IUCN Status=%{x}<extra></extra>", "legendgroup": "Schedule-IV", "marker": {"color": "rgb(177, 127, 38)"}, "name": "Schedule-IV", "offsetgroup": "Schedule-IV", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Least Concern", "Least Concern", "Least Concern", "Least Concern", "Least Concern", "Vulnerable", "Least Concern", "Least Concern", "Least Concern", "Least
# ...

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>🎉 Schedule-IV and V comprise mostly the least concerning bird species. Schedule-I appears to be more than Schedule-IV for critically endangered species. Examples for each WLPA schedule in endangered species are presented below. </div>

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#80471C">WLPA Schedule for IUCN Status</h2>
# <h3 style='font-family: Comic Sans MS;color:black;background-color:#CBAACB;'>Critically Endangered</h3>
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#177C99;'>Schedule-I</h4>
#
# ![1-min.jpg](attachment:65a2a661-abb6-49ab-aaf5-acc04f8add8a.jpg)
#
# White-rumped Vulture
#
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#F1B02F;'>Schedule-IV</h4>
#
# ![3-min.jpg](attachment:5d475f54-6ec2-4cf5-b296-44e09baa9492.jpg)
#
# Red-headed Vulture
#
#
# <h3 style='font-family: Comic Sans MS;color:black;background-color:#F3B0C3;'>Endangered</h3>
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#F1B02F;'>Schedule-IV</h4>
#
# ![4-min.jpg](attachment:b3d6bfd2-c893-49d1-bf49-92d9517aefc5.jpg)
#
# Egyptian Vulture

# %%
t = df[df['IUCN Status'] == 'Critically Endangered']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'IUCN Status', 'WLPA Schedule']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 242            Red-headed Vulture                  Sarcogyps calvus
# 244          White-rumped Vulture                  Gyps bengalensis
# 245                Indian Vulture                      Gyps indicus
#
#                IUCN Status WLPA Schedule
# 242  Critically Endangered   Schedule-IV
# 244  Critically Endangered    Schedule-I
# 245  Critically Endangered    Schedule-I

# %%
t = df[df['IUCN Status'] == 'Endangered']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'IUCN Status', 'WLPA Schedule']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 238              Egyptian Vulture             Neophron percnopterus
#
#     IUCN Status WLPA Schedule
# 238  Endangered   Schedule-IV

# %% [markdown]
# <h2 id='sec12' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> CURRENT STATUS FOR EACH IUCN STATUS </h2>

# %%
fig = make_subplots(rows = 3, cols = 2, specs=[[{"type": "pie"}, {"type": "pie"}], [{"type": "pie"}, {"type": "pie"}], [{"type": "pie"}, {"type": "pie"}]])
fig.add_trace(go.Pie(labels = df[df['IUCN Status'] == 'Least Concern']['Current Status'].value_counts().index, values = df[df['IUCN Status'] == 'Least Concern']['Current Status'].value_counts().values, name = 'Least Concern'), 1, 1)
fig.add_trace(go.Pie(labels = df[df['IUCN Status'] == 'Vulnerable']['Current Status'].value_counts().index, values = df[df['IUCN Status'] == 'Vulnerable']['Current Status'].value_counts().values, name = 'Vulnerable'), 1, 2)
fig.add_trace(go.Pie(labels = df[df['IUCN Status'] == 'Near Threatened']['Current Status'].value_counts().index, values = df[df['IUCN Status'] == 'Near Threatened']['Current Status'].value_counts().values, name = 'Near Threatened'), 2, 1)
fig.add_trace(go.Pie(labels = df[df['IUCN Status'] == 'Endangered']['Current Status'].value_counts().index, values = df[df['IUCN Status'] == 'Endangered']['Current Status'].value_counts().values, name = 'Endangered'), 2, 2)
fig.add_trace(go.Pie(labels = df[df['IUCN Status'] == 'Critically Endangered']['Current Status'].value_counts().index, values = df[df['IUCN Status'] == 'Critically Endangered']['Current Status'].value_counts().values, name = 'Critically Endangered'), 3, 1)
fig.update_traces(hole=.4)
fig.update(layout_showlegend = True)
fig.update_layout(title_text = "Current Status for IUCN Status", annotations=[dict(text = 'Least Concern', x = 0.0, y = 1.1, font_size = 14, showarrow = False), dict(text = 'Vulnerable', x = 0.7, y = 1.1, font_size = 14, showarrow = False), dict(text = 'Near Threatened', x = -0.05, y = 0.7, font_size = 14, showarrow = False), dict(text = 'Endangered', x = 0.7, y = 0.7, font_size = 14, showarrow=False), dict(text = 'Critically Endangered', x = -0.095, y = 0.3, font_size = 14, showarrow = False)])
# Out:
# <div>                            <div id="453c04b0-d895-450a-802a-3437ba351638" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("453c04b0-d895-450a-802a-3437ba351638")) {                    Plotly.newPlot(                        "453c04b0-d895-450a-802a-3437ba351638",                        [{"domain": {"x": [0.0, 0.45], "y": [0.7333333333333333, 1.0]}, "hole": 0.4, "labels": ["Uncertain", "Strong Decline", "Moderate Decline", "Stable", "Strong Increase", "Moderate Increase"], "name": "Least Concern", "type": "pie", "values": [145, 42, 28, 9, 8, 2]}, {"domain": {"x": [0.55, 1.0], "y": [0.7333333333333333, 1.0]}, "hole": 0.4, "labels": ["Moderate Decline", "Uncertain", "Strong Decline"], "name": "Vulnerable", "type": "pie", "values": [2, 1, 1]}, {"dom
# ...

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>🎆 Though IUCN Status is Least Concern, it is suprising that 30% of those bird species are currently declining. On the other hand, endangered species are all strongly declining. Currently increasing species are only amongst least concerning species and none of the concerning species. A few examples from these observations are presented below. </div>

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#FF5412">Least Concerning but Strongly Declining</h2>
# Pacific Golden Plover
#
# ![11-min.jpg](attachment:9ac138cd-5a3d-4ee8-ad8d-a12d30f2123f.jpg)
#
# Cinnamon Bittern
#
# ![12-min.jpg](attachment:9d78ede0-c5f4-47ff-8ba5-8b129b2ef4ec.jpg)
#
# Heart-spotted Woodpecker
#
# ![13-min.jpg](attachment:1c732684-3a1c-42d9-bfbd-46593c30cf06.jpg)

# %%
t = df[df['IUCN Status'] == 'Least Concern']
t = t[t['Current Status'] == 'Strong Decline']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'IUCN Status', 'Current Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 6                     Cotton Teal          Nettapus coromandelianus
# 57                   Little Grebe            Tachybaptus ruficollis
# 107                 Indian Cuckoo               Cuculus micropterus
# 120             Crested Treeswift               Hemiprocne coronata
# 123                   Common Coot                       Fulica atra
# 124               Purple Swamphen               Porphyrio porphyrio
# 143         Pacific Golden Plover                   Pluvialis fulva
# 146        Yellow-wattled Lapwing              Vanellus malabaricus
# 174              Common Sandpiper                Actitis hypoleucos
# 183                Indian Courser          Cursorius coromandelicus
# 195                Whiskered Tern                Chlidonias hybrida
# 202                Asian Openbill                Anastomus oscitans
# 210              Little Cormorant                  Microcarbo niger
# ...

# %% [markdown]
# <h2 id='sec13' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> MIGRATORY STATUS FOR EACH CURRENT STATUS </h2>

# %%
plt.figure(figsize = (20, 6))
sns.countplot(x = "Current Status", hue = "Migratory Status", data = df, palette = 'Paired')
plt.show()

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>✨ The stable and the increasing bird species do not consist of long distance and local birds but they purely consist of resident birds. The non resident birds occupy the uncertain and declining spaces. A example for each migratory status in strongly declining birds is presented below. </div>

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#597D35"> Migratory Status of Strongly Declining Birds</h2>
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#95D8EB;'>Resident</h4>
#
# ![14-min.jpg](attachment:3c4cb764-d8b0-4279-8c0a-36b25eb1de0c.jpg)
#
# Cotton Teal
#
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#00677A;'>Migratory-Long-Distance</h4>
#
# ![15-min.jpg](attachment:1788861b-11c2-4387-87e6-7d1c8cb9f100.jpg)
#
# Forest Wagtail
#
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#97DC21;'>Migratory-Local</h4>
#
# ![16-min.jpg](attachment:5df7790e-0fa1-4490-874e-2d8268ee6bf5.jpg)
#
# Crested Bunting

# %%
t = df[df['Current Status'] == 'Strong Decline']
t = t[t['Migratory Status'] == 'Resident']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Current Status', 'Migratory Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 6                     Cotton Teal          Nettapus coromandelianus
# 57                   Little Grebe            Tachybaptus ruficollis
# 107                 Indian Cuckoo               Cuculus micropterus
# 120             Crested Treeswift               Hemiprocne coronata
# 123                   Common Coot                       Fulica atra
# 124               Purple Swamphen               Porphyrio porphyrio
# 146        Yellow-wattled Lapwing              Vanellus malabaricus
# 183                Indian Courser          Cursorius coromandelicus
# 195                Whiskered Tern                Chlidonias hybrida
# 202                Asian Openbill                Anastomus oscitans
# 210              Little Cormorant                  Microcarbo niger
# 217              Cinnamon Bittern            Ixobrychus cinnamomeus
# 221                  Purple Heron                    Ardea purpurea
# ...

# %%
t = df[df['Current Status'] == 'Strong Decline']
t = t[t['Migratory Status'] == 'Migratory-Long-Distance']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Current Status', 'Migratory Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 143         Pacific Golden Plover                   Pluvialis fulva
# 174              Common Sandpiper                Actitis hypoleucos
# 807                Forest Wagtail             Dendronanthus indicus
#
#      Current Status         Migratory Status
# 143  Strong Decline  Migratory-Long-Distance
# 174  Strong Decline  Migratory-Long-Distance
# 807  Strong Decline  Migratory-Long-Distance

# %%
t = df[df['Current Status'] == 'Strong Decline']
t = t[t['Migratory Status'] == 'Migratory-Local']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Current Status', 'Migratory Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 843               Crested Bunting                  Emberiza lathami
#
#      Current Status Migratory Status
# 843  Strong Decline  Migratory-Local

# %% [markdown]
# <h2 id='sec14' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> DISTRIBUTION STATUS FOR EACH LONG TERM STATUS </h2>

# %%
fig, axes = plt.subplots(3, 2, figsize=(15,12))

mosaic(df.loc[df['Long Term Status'] == 'Strong Increase'], ['Distribution Status'], title = 'Strong Increase', label_rotation = 0.0, labelizer = lambda k: df.loc[df['Long Term Status'] == 'Strong Increase']['Distribution Status'].str.count(k[0]).sum(), ax = axes[0][0])
mosaic(df.loc[df['Long Term Status'] == 'Moderate Increase'], ['Distribution Status'], title = 'Moderate Increase', label_rotation = 0.0, labelizer = lambda k: df.loc[df['Long Term Status'] == 'Moderate Increase']['Distribution Status'].str.count(k[0]).sum(), ax = axes[0][1])
mosaic(df.loc[df['Long Term Status'] == 'Stable'], ['Distribution Status'], title = 'Stable', label_rotation = 0.0, labelizer = lambda k: df.loc[df['Long Term Status'] == 'Stable']['Distribution Status'].str.count(k[0]).sum(), ax = axes[1][0])
mosaic(df.loc[df['Long Term Status'] == 'Moderate Decline'], ['Distribution Status'], title = 'Moderate Decline', label_rotation = 0.0, labelizer = lambda k: df.loc[df['Long Term Status'] == 'Moderate Decline']['Distribution Status'].str.count(k[0]).sum(), ax = axes[1][1])
mosaic(df.loc[df['Long Term Status'] == 'Strong Decline'], ['Distribution Status'], title = 'Strong Decline', label_rotation = 0.0, labelizer = lambda k: df.loc[df['Long Term Status'] == 'Strong Decline']['Distribution Status'].str.count(k[0]).sum(), ax = axes[2][0])

axes[2,1].set_axis_off()
fig.suptitle('Distribution Status for each Long Term Status')
fig.show()

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>🎊 The bird species that have an increasing long term trend are of only very large distribution statuses. Restricted distribution status is seen in the species that are strongly declining long term. A few examples for each distribution status in strongly long term declining species is presented below. </div>

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#80471C">Distribution Status of Strongly Declining Birds</h2>
# <h4 style='font-family: Comic Sans MS;color:white;background-color:#940128;'>Very Large</h4>
#
# ![17-min.jpg](attachment:b75ee4cc-189a-448f-9f21-396cea89e665.jpg)
#
# Short-toed Snake Eagle
#
# ![18-min.jpg](attachment:170fd6ca-c7fd-4c44-aee4-78a524f46d36.jpg)
#
# Common Woodshrike
#
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#005ABC;'>Restricted</h4>
#
# ![38-min.jpg](attachment:0642f310-4045-43fa-806a-8d88ca8ba803.jpg)
#
# Gull-billed Tern
#
# ![39-min.jpg](attachment:229838db-af81-46bd-ada9-e7584f8b6c47.jpg)
#
# Grey-sided Laughingthrush

# %%
t = df[df['Long Term Status'] == 'Strong Decline']
t = t[t['Distribution Status'] == 'Very Large']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long Term Status', 'Distribution Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 6                     Cotton Teal          Nettapus coromandelianus
# 252        Short-toed Snake Eagle                Circaetus gallicus
# 380             Common Woodshrike        Tephrodornis pondicerianus
# 386                 Small Minivet          Pericrocotus cinnamomeus
#
#     Long Term Status Distribution Status
# 6     Strong Decline          Very Large
# 252   Strong Decline          Very Large
# 380   Strong Decline          Very Large
# 386   Strong Decline          Very Large

# %%
t = df[df['Long Term Status'] == 'Strong Decline']
t = t[t['Distribution Status'] == 'Restricted']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long Term Status', 'Distribution Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 193              Gull-billed Tern             Gelochelidon nilotica
# 649     Grey-sided Laughingthrush               Garrulax caerulatus
#
#     Long Term Status Distribution Status
# 193   Strong Decline          Restricted
# 649   Strong Decline          Restricted

# %% [markdown]
# <h2 id='sec15' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> LONG TERM STATUS Vs CURRENT STATUS </h2>

# %%
plt.rcParams['figure.figsize']= (15, 7)
sns.heatmap(pd.crosstab(df['Long Term Status'], df['Current Status']), cmap = 'Spectral', annot = True)
plt.show()

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>🔔 Birds species that were thought to be stable and unceratin long term seem to be uncertain, stable, or declining currently for the most part. They are rarely increasing currently. As expected, the increasing and declining species long term follow the same trend currently as well. A few examples of the strongly declining species long term as well as currently are presented below. </div>

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#FF781F">Strong Decline (Long Term Status and Current Status)</h2>
# Crested Treeswift
#
# ![20-min.jpg](attachment:f8c9613e-6c4a-48ab-9b26-42321a4face5.jpg)
#
# Small Minivet
#
# ![21-min.jpg](attachment:64298de6-af87-41d5-8786-0ab26a802002.jpg)
#
# Rufous-fronted Prinia
#
# ![22-min.jpg](attachment:fd755e21-7bf5-40f4-86ff-bc1dba72c573.jpg)

# %%
t = df[df['Long Term Status'] == 'Strong Decline']
t = t[t['Current Status'] == 'Strong Decline']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long Term Status', 'Current Status']]
# Out:
#     Common Name (India Checklist) Scientific Name (India Checklist)  \
# 6                     Cotton Teal          Nettapus coromandelianus
# 120             Crested Treeswift               Hemiprocne coronata
# 143         Pacific Golden Plover                   Pluvialis fulva
# 217              Cinnamon Bittern            Ixobrychus cinnamomeus
# 242            Red-headed Vulture                  Sarcogyps calvus
# 244          White-rumped Vulture                  Gyps bengalensis
# 245                Indian Vulture                      Gyps indicus
# 252        Short-toed Snake Eagle                Circaetus gallicus
# 261                   Tawny Eagle                      Aquila rapax
# 334      Heart-spotted Woodpecker                Hemicircus canente
# 361             Red-necked Falcon                   Falco chicquera
# 380             Common Woodshrike        Tephrodornis pondicerianus
# 386                 Small Minivet          Pericrocotus cinnamomeus
# ...

# %% [markdown]
# <h2 id='sec16' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> 10 MOST DECREASING IN ABUNDANCE BIRD SPECIES IN THE LAST 5 YEARS  </h2>

# %%
px.bar(df.sort_values('Current Annual Change (%)', ascending = True)[ : 10], y = "Current Annual Change (%)", x = "Common Name (India Checklist)", error_y = 'Current Annual Change CI (%)', color = 'Current Status', color_discrete_map = {"Strong Decline" : "#4A2C2C"})
# Out:
# <div>                            <div id="8fefb3cf-ca99-40ae-86ad-cf538544cf0c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8fefb3cf-ca99-40ae-86ad-cf538544cf0c")) {                    Plotly.newPlot(                        "8fefb3cf-ca99-40ae-86ad-cf538544cf0c",                        [{"alignmentgroup": "True", "error_y": {"array": [4.220555399, 3.03821425, 8.0705595, 4.507116842, 2.276498045, 5.35015162, 4.463637451, 3.387230038, 3.885776179, 5.952840035]}, "hovertemplate": "Current Status=Strong Decline<br>Common Name (India Checklist)=%{x}<br>Current Annual Change (%)=%{y}<extra></extra>", "legendgroup": "Strong Decline", "marker": {"color": "#4A2C2C"}, "name": "Strong Decline", "offsetgroup": "Strong Decline", "orientation": "v", "showlege
# ...

# %% [markdown]
# <h2 id='sec17' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> 10 MOST INCREASING IN ABUNDANCE BIRD SPECIES IN THE LAST 5 YEARS  </h2>

# %%
px.bar(df.sort_values('Current Annual Change (%)', ascending = False)[ :10], y = "Current Annual Change (%)", x = "Common Name (India Checklist)", error_y = 'Current Annual Change CI (%)', color = 'Current Status', color_discrete_map = {"Strong Increase" : "#E3BC9A", "Uncertain" : '#FDD400', "Moderate Increase" : '#FF9205'})
# Out:
# <div>                            <div id="dd442665-7a1e-4c1e-b6d0-104e462d9f48" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("dd442665-7a1e-4c1e-b6d0-104e462d9f48")) {                    Plotly.newPlot(                        "dd442665-7a1e-4c1e-b6d0-104e462d9f48",                        [{"alignmentgroup": "True", "error_y": {"array": [6.581857068, 2.131361113, 4.555680898, 5.333940767, 5.331043552, 3.179564718, 2.303397302]}, "hovertemplate": "Current Status=Strong Increase<br>Common Name (India Checklist)=%{x}<br>Current Annual Change (%)=%{y}<extra></extra>", "legendgroup": "Strong Increase", "marker": {"color": "#E3BC9A"}, "name": "Strong Increase", "offsetgroup": "Strong Increase", "orientation": "v", "showlegend": true, "textposition": "aut
# ...

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#969E67">Current Annual Change (%)</h2>
# <h4 style='font-family: Comic Sans MS;color:white;background-color:#4A2C2C;'>Strong Decline</h4>
#
# ![3-min.jpg](attachment:42ededfc-f63f-475c-b0eb-f405f7e53dfc.jpg)
#
# Red-headed Vulture
#
# ![1-min.jpg](attachment:d3311f13-6154-49bb-b3b8-2e874cbd8f50.jpg)
#
# White-rumped Vulture
#
#
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#E3BC9A;'>Strong Increase</h4>
#
# ![37-min.jpg](attachment:f69fd526-f633-4345-bf18-3257a74c9900.jpg)
#
# Brown Rock Chat
#
# ![23-min.jpg](attachment:ad0f86f6-7db1-491e-9299-3d7e569ce33a.jpg)
#
# Rock Pigeon

# %% [markdown]
# <h2 id='sec18' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> 10 MOST DECREASING IN ABUNDANCE BIRD SPECIES IN 25+ YEARS  </h2>

# %%
px.bar(df.sort_values('Long-term Trend (%)')[ : 10], y = "Long-term Trend (%)", x = "Common Name (India Checklist)", error_y = 'Long-term Trend CI (%)', color = 'Long Term Status', color_discrete_map = {"Strong Decline" : "#FF5412"})
# Out:
# <div>                            <div id="7fc2fc98-43df-4f89-87a3-9e71025effc1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7fc2fc98-43df-4f89-87a3-9e71025effc1")) {                    Plotly.newPlot(                        "7fc2fc98-43df-4f89-87a3-9e71025effc1",                        [{"alignmentgroup": "True", "error_y": {"array": [0.914415322999986, 4.260556302, 5.844151486, 8.658632845, 6.471064845, 8.066862125, 9.628684269, 10.92549614, 12.57116823, 14.55160702]}, "hovertemplate": "Long Term Status=Strong Decline<br>Common Name (India Checklist)=%{x}<br>Long-term Trend (%)=%{y}<extra></extra>", "legendgroup": "Strong Decline", "marker": {"color": "#FF5412"}, "name": "Strong Decline", "offsetgroup": "Strong Decline", "orientation": "v", "sh
# ...

# %% [markdown]
# <h2 id='sec19' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> 10 MOST INCREASING IN ABUNDANCE BIRD SPECIES IN 25+ YEARS  </h2>

# %%
px.bar(df.sort_values('Long-term Trend (%)', ascending = False)[ : 10], y = "Long-term Trend (%)", x = "Common Name (India Checklist)", error_y = 'Long-term Trend CI (%)', color = 'Long Term Status', color_discrete_map = {"Stable" : '#2FF3E0', "Uncertain" : "#F18620", "Moderate Increase" : "#44EE77", "Strong Increase" : "#019992"})
# Out:
# <div>                            <div id="0cd0fac3-988d-47cb-b8be-3589f949c17d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("0cd0fac3-988d-47cb-b8be-3589f949c17d")) {                    Plotly.newPlot(                        "0cd0fac3-988d-47cb-b8be-3589f949c17d",                        [{"alignmentgroup": "True", "error_y": {"array": [27.01840809]}, "hovertemplate": "Long Term Status=Strong Increase<br>Common Name (India Checklist)=%{x}<br>Long-term Trend (%)=%{y}<extra></extra>", "legendgroup": "Strong Increase", "marker": {"color": "#019992"}, "name": "Strong Increase", "offsetgroup": "Strong Increase", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Rock Pigeon"], "xaxis": "x", "y": [143.9681557], "yaxis"
# ...

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#E7D5AD">Long-term Trend (%)</h2>
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#FF5412;'>Strong Decline</h4>
#
# ![1-min.jpg](attachment:0b788838-37e4-4d85-8be9-115b8b9fa660.jpg)
#
# White-rumped Vulture
#
# ![2-min.jpg](attachment:2545b260-eb82-4f03-96e8-07c2f54e1801.jpg)
#
# Indian Vulture
#
#
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#019992;'>Strong Increase</h4>
#
# ![23-min.jpg](attachment:242c1910-905e-4468-9b74-dff8e967c558.jpg)
#
# Rock Pigeon

# %% [markdown]
# <h2 id='sec20' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> 10 MOST DECREASING IN DISTRIBUTION BIRD SPECIES IN THE LAST 5 YEARS  </h2>

# %%
px.bar(df.sort_values('Distribution Range Size (units of 10,000 sq. km.)')[ : 10], x = "Distribution Range Size (units of 10,000 sq. km.)", y = "Common Name (India Checklist)", error_x = 'Distribution Range Size CI (units of 10,000 sq. km.)', color = 'Distribution Status', color_discrete_map = {"Restricted" : "#FEC20F", "Moderate" : '#C64B8C'})
# Out:
# <div>                            <div id="d5049855-8fa0-4cf7-aa79-921a9eb80df3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d5049855-8fa0-4cf7-aa79-921a9eb80df3")) {                    Plotly.newPlot(                        "d5049855-8fa0-4cf7-aa79-921a9eb80df3",                        [{"alignmentgroup": "True", "error_x": {"array": [0.0660000000000003, 0.0486]}, "hovertemplate": "Distribution Status=Restricted<br>Distribution Range Size (units of 10,000 sq. km.)=%{x}<br>Common Name (India Checklist)=%{y}<extra></extra>", "legendgroup": "Restricted", "marker": {"color": "#FEC20F"}, "name": "Restricted", "offsetgroup": "Restricted", "orientation": "h", "showlegend": true, "textposition": "auto", "type": "bar", "x": [2.2370902, 3.6441452], "xaxis
# ...

# %% [markdown]
# <h2 id='sec21' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> 10 MOST INCREASING IN ABUNDANCE BIRD SPECIES IN THE LAST 5 YEARS  </h2>

# %%
px.bar(df.sort_values('Distribution Range Size (units of 10,000 sq. km.)')[-10 : ], x = "Distribution Range Size (units of 10,000 sq. km.)", y = "Common Name (India Checklist)", error_x = 'Distribution Range Size CI (units of 10,000 sq. km.)', color = 'Distribution Status', color_discrete_map = {"Very Large" : '#315A39'})
# Out:
# <div>                            <div id="74c71a37-47b7-4177-bdd3-a9fbf017d089" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("74c71a37-47b7-4177-bdd3-a9fbf017d089")) {                    Plotly.newPlot(                        "74c71a37-47b7-4177-bdd3-a9fbf017d089",                        [{"alignmentgroup": "True", "error_x": {"array": [0.0865000000000009, 0.0705000000000098, 0.0745000000000005, 0.0711000000000013, 0.0728000000000009, 0.0622999999999934, 0.0656999999999925, 0.0759999999999934, 0.0622999999999934, 0.0690999999999917]}, "hovertemplate": "Distribution Status=Very Large<br>Distribution Range Size (units of 10,000 sq. km.)=%{x}<br>Common Name (India Checklist)=%{y}<extra></extra>", "legendgroup": "Very Large", "marker": {"color": "#315
# ...

# %% [markdown]
# <h2 style = "font-family: Comic Sans MS;background-color:#B999FF">Distribution Range Size (units of 10,000 sq. km.)</h2>
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#FEC20F;'>Restricted</h4>
#
# ![38-min.jpg](attachment:1a94fdd4-7393-4941-bef9-0d93fb7268c9.jpg)
#
# Gull-billed Tern
#
# ![39-min.jpg](attachment:a54df628-6f38-4949-bbcb-6fb3ca5a2bdc.jpg)
#
# Grey-sided Laughingthrush
#
#
# <h4 style='font-family: Comic Sans MS;color:white;background-color:#315A39;'>Very Large</h4>
#
# ![27-min.jpg](attachment:d86ede10-5ae0-4e38-a244-42dd097573b4.jpg)
#
# Black Drongo
#
# ![28-min.jpg](attachment:13b2e3c8-48b6-49c2-b97f-d05dfd37a875.jpg)
#
# Common Myna

# %% [markdown]
# <h3 id='sec22' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> HOW DOES CURRENT ANNUAL CHANGE RELATE TO THE CURRENT STATUS AND THE IUCN STATUS?  </h3>

# %%
px.box(df, x = 'Current Status', y = "Current Annual Change (%)", points = "all", color = 'IUCN Status', color_discrete_map = {"Least Concern" : "#E3BC9A", "Vulnerable" : '#FDD400', "Near Threatened" : '#FF9205', "Endangered" : "#CE5501", "Critically Endangered" : "#4A2C2C"})
# Out:
# <div>                            <div id="540d9297-ef14-4791-b000-8c60911b8ce1" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("540d9297-ef14-4791-b000-8c60911b8ce1")) {                    Plotly.newPlot(                        "540d9297-ef14-4791-b000-8c60911b8ce1",                        [{"alignmentgroup": "True", "boxpoints": "all", "hovertemplate": "IUCN Status=Least Concern<br>Current Status=%{x}<br>Current Annual Change (%)=%{y}<extra></extra>", "legendgroup": "Least Concern", "marker": {"color": "#E3BC9A"}, "name": "Least Concern", "notched": false, "offsetgroup": "Least Concern", "orientation": "v", "showlegend": true, "type": "box", "x": ["Moderate Decline", "Strong Decline", "Uncertain", "Uncertain", "Moderate Decline", "Uncertain", "Mode
# ...

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>📌 The least concerning species are either only stable or increasing with mostly positive long term trends. The concerning species seem to be declining with negative long term trends. Though some species are currently uncertain, from the boxplot above, they have similar traits to that of declining species. The least concerning species which are strongly increasing have a high current annual change as high as 11%. The critically endangered species which are strongly declining have a low current annual change as low as -18%. Examples of these species are presented below. </div>

# %% [markdown]
# <h4 style = "font-family: Comic Sans MS;color:white;background-color:#4A2C2C;"> Critically Endangered (IUCN Status) + [-18, -10] % (Current Annual Change) + Strong Decline (Current Status)</h4>
# White-rumped Vulture
#
# ![1-min.jpg](attachment:7aad56a4-2b8a-4162-8810-9027ac113bfc.jpg)
#
# Red-headed Vulture
#
# ![3-min.jpg](attachment:1221b136-bd09-4320-9566-592e5ab37c36.jpg)
#
# Indian Vulture
#
# ![2-min.jpg](attachment:ca3d9706-90e4-4ae3-af1d-e22d1274b79c.jpg)

# %%
t = df[df['IUCN Status'] == 'Critically Endangered']
t[['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'IUCN Status', 'Current Annual Change (%)', 'Current Status']].style.background_gradient(cmap = 'BrBG')
# Out:
# <style  type="text/css" >
# #T_0550743a_9f92_11eb_956c_0242ac130202row0_col3{
#             background-color:  #543005;
#             color:  #f1f1f1;
#         }#T_0550743a_9f92_11eb_956c_0242ac130202row1_col3{
#             background-color:  #583305;
#             color:  #f1f1f1;
#         }#T_0550743a_9f92_11eb_956c_0242ac130202row2_col3{
#             background-color:  #003c30;
#             color:  #f1f1f1;
#         }</style><table id="T_0550743a_9f92_11eb_956c_0242ac130202" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Common Name (India Checklist)</th>        <th class="col_heading level0 col1" >Scientific Name (India Checklist)</th>        <th class="col_heading level0 col2" >IUCN Status</th>        <th class="col_heading level0 col3" >Current Annual Change (%)</th>        <th class="col_heading level0 col4" >Current Status</th>    </tr></thead><tbody>
#                 <tr>
# ...

# %% [markdown]
# <h4 id='sec23' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> HOW DO ALL THE TRENDS RELATE TO THE DISTRIBUTION STATUS FOR LEAST CONCERNING SPECIES?  </h4>

# %%
df_least = df[df['IUCN Status'] == 'Least Concern']
px.scatter(df_least, x = "Current Annual Change (%)", y = "Long-term Trend (%)", color = "Distribution Status", size = 'Distribution Range Size (units of 10,000 sq. km.)', hover_name = "Common Name (India Checklist)", color_discrete_map = {"Moderate" : "#FF5412", "Restricted" : '#FF5765', "Large" : "#44EE77", "Very Large" : "#019992"})
# Out:
# <div>                            <div id="1f8f820c-6691-4a65-818a-8f264716653a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1f8f820c-6691-4a65-818a-8f264716653a")) {                    Plotly.newPlot(                        "1f8f820c-6691-4a65-818a-8f264716653a",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Distribution Status=Very Large<br>Current Annual Change (%)=%{x}<br>Long-term Trend (%)=%{y}<br>Distribution Range Size (units of 10,000 sq. km.)=%{marker.size}<extra></extra>", "hovertext": ["Lesser Whistling Duck", "Cotton Teal", "Indian Spot-billed Duck", "Grey Francolin", "Little Grebe", "Rock Pigeon", "Eurasian Collared Dove", "Red Collared Dove", "Spotted Dove", "Laughing Dove", "Greater Coucal", "Asian Koel", "
# ...

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>📍 The species with high long term trends, current annual changes, and distribution ranges have a very large distribution status. The species with low trends have a moderate distribution status. As seen in the bubble chart above, the bubbles that are further to the left, low, and small are red whereas the ones that are further to the right, top, and big are green. Since they are species of least concern, the number of species that are not largely distributed are not as high. A few examples from the graph above are presented below. </div>

# %% [markdown]
# <h4 style = "font-family: Comic Sans MS;background-color:#E7D5AD"> LEAST CONCERN (IUCN STATUS) => Long-term Trend + Current Annual Change + Distribution Range Size + Distribution Status</h4>
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#FF5412;'>Moderate (Distribution Status)</h4>
#
# ![11-min.jpg](attachment:522bd0e5-ebdb-4aa1-a78e-b2b267f34fe0.jpg)
#
# Pacific Golden Plover
#
# ![32-min.jpg](attachment:2e1f2657-521c-4aeb-a2c1-f44b8ed97900.jpg)
#
# Common Kestrel
#
#
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#019992;'>Very Large (Distribution Status)</h4>
#
# ![23-min.jpg](attachment:6e2a68a1-cf44-48f2-8444-4be9babbe582.jpg)
#
# Rock Pigeon
#
# ![31-min.jpg](attachment:b619f8dc-36e2-49bc-a1ae-af6b8d46e192.jpg)
#
# Asian Koel

# %%
a = df[df["Common Name (India Checklist)"] == 'Pacific Golden Plover'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Current Annual Change (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Distribution Status']]
a = a.append(df[df["Common Name (India Checklist)"] == 'Common Kestrel'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Current Annual Change (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Distribution Status']])
a.style.background_gradient(cmap = 'autumn')
# Out:
# <style  type="text/css" >
# #T_064d2572_9f92_11eb_956c_0242ac130202row0_col2,#T_064d2572_9f92_11eb_956c_0242ac130202row0_col4,#T_064d2572_9f92_11eb_956c_0242ac130202row1_col3{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_064d2572_9f92_11eb_956c_0242ac130202row0_col3,#T_064d2572_9f92_11eb_956c_0242ac130202row1_col2,#T_064d2572_9f92_11eb_956c_0242ac130202row1_col4{
#             background-color:  #ffff00;
#             color:  #000000;
# ...

# %%
a = df[df["Common Name (India Checklist)"] == 'Rock Pigeon'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Current Annual Change (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Distribution Status']]
a = a.append(df[df["Common Name (India Checklist)"] == 'Asian Koel'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Current Annual Change (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Distribution Status']]
)
a.style.background_gradient(cmap = 'viridis')
# Out:
# <style  type="text/css" >
# #T_067f39a4_9f92_11eb_956c_0242ac130202row0_col2,#T_067f39a4_9f92_11eb_956c_0242ac130202row0_col3,#T_067f39a4_9f92_11eb_956c_0242ac130202row0_col4{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_067f39a4_9f92_11eb_956c_0242ac130202row1_col2,#T_067f39a4_9f92_11eb_956c_0242ac130202row1_col3,#T_067f39a4_9f92_11eb_956c_0242ac130202row1_col4{
#             background-color:  #440154;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# <h3 id='sec24' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> HOW DO ALL THE TRENDS RELATE TO THE DISTRIBUTION STATUS FOR CONCERNING SPECIES?  </h3>

# %%
df_most = df[df['IUCN Status'] != 'Least Concern']
px.scatter(df_most, x = "Current Annual Change (%)", y = "Long-term Trend (%)", color = "Distribution Status", size = 'Distribution Range Size (units of 10,000 sq. km.)', hover_name = "Common Name (India Checklist)", color_discrete_map = {"Moderate" : "#FF5412", "Restricted" : '#FF5765', "Large" : "#44EE77", "Very Large" : "#019992"})
# Out:
# <div>                            <div id="d7366b14-7946-4ea0-8a6a-0734cf4a1de3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("d7366b14-7946-4ea0-8a6a-0734cf4a1de3")) {                    Plotly.newPlot(                        "d7366b14-7946-4ea0-8a6a-0734cf4a1de3",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Distribution Status=Large<br>Current Annual Change (%)=%{x}<br>Long-term Trend (%)=%{y}<br>Distribution Range Size (units of 10,000 sq. km.)=%{marker.size}<extra></extra>", "hovertext": ["Common Pochard", "Sarus Crane", "Great Thick-knee", "River Lapwing", "Black-tailed Godwit", "Egyptian Vulture", "Tawny Eagle", "Red-necked Falcon"], "legendgroup": "Large", "marker": {"color": "#44EE77", "size": [56.7869682, 33.14364
# ...

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>⏳ The species with high long term trends, current annual changes, and distribution ranges have a very large distribution status. The species with low trends have a moderate distribution status. As seen in the bubble chart above, the bubbles that are further to the left, low, and small are red whereas the ones that are further to the right, top, and big are green. Since they are species of concern, the number of species that are not largely distributed are high. Also, note that even though some species have a very large distribution range and status, they have low long term trends and current annual change. This explains why they are under the concerning species. A few examples from the graph above are presented below. </div>

# %% [markdown]
# <h4 style = "font-family: Comic Sans MS;background-color:#E7D5AD"> CONCERN (IUCN STATUS) => Long-term Trend + Current Annual Change + Distribution Range Size + Distribution Status</h4>
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#FF5412;'>Moderate (Distribution Status)</h4>
#
# ![1-min.jpg](attachment:7d08da6c-e9b1-4c0a-ab84-73025f735c78.jpg)
#
# White-rumped Vulture
#
# ![3-min.jpg](attachment:f5974b3b-bec0-404f-a83e-5410d308f184.jpg)
#
# Red-headed Vulture
#
#
# <h4 style='font-family: Comic Sans MS;color:black;background-color:#019992;'>Very Large (Distribution Status)</h4>
#
# ![29-min.jpg](attachment:c70fcad8-5eb0-4fd2-b2c4-7a15ff5088bd.jpg)
#
# Oriental Darter
#
# ![30-min.jpg](attachment:c723ee49-d4ba-4eab-9c9c-f41d208d03ac.jpg)
#
# Woolly-necked Stork

# %%
a = df[df["Common Name (India Checklist)"] == 'White-rumped Vulture'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Current Annual Change (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Distribution Status']]
a = a.append(df[df["Common Name (India Checklist)"] == 'Red-headed Vulture'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Current Annual Change (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Distribution Status']])
a.style.background_gradient(cmap = 'autumn')
# Out:
# <style  type="text/css" >
# #T_077dbfe2_9f92_11eb_956c_0242ac130202row0_col2,#T_077dbfe2_9f92_11eb_956c_0242ac130202row1_col3,#T_077dbfe2_9f92_11eb_956c_0242ac130202row1_col4{
#             background-color:  #ff0000;
#             color:  #f1f1f1;
#         }#T_077dbfe2_9f92_11eb_956c_0242ac130202row0_col3,#T_077dbfe2_9f92_11eb_956c_0242ac130202row0_col4,#T_077dbfe2_9f92_11eb_956c_0242ac130202row1_col2{
#             background-color:  #ffff00;
#             color:  #000000;
# ...

# %%
a = df[df["Common Name (India Checklist)"] == 'Oriental Darter'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Current Annual Change (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Distribution Status']]
a = a.append(df[df["Common Name (India Checklist)"] == 'Woolly-necked Stork'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Current Annual Change (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Distribution Status']])
a.style.background_gradient(cmap = 'viridis')
# Out:
# <style  type="text/css" >
# #T_07b0c4dc_9f92_11eb_956c_0242ac130202row0_col2,#T_07b0c4dc_9f92_11eb_956c_0242ac130202row0_col3,#T_07b0c4dc_9f92_11eb_956c_0242ac130202row1_col4{
#             background-color:  #fde725;
#             color:  #000000;
#         }#T_07b0c4dc_9f92_11eb_956c_0242ac130202row0_col4,#T_07b0c4dc_9f92_11eb_956c_0242ac130202row1_col2,#T_07b0c4dc_9f92_11eb_956c_0242ac130202row1_col3{
#             background-color:  #440154;
#             color:  #f1f1f1;
# ...

# %% [markdown]
# <h3 id='sec25' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> HOW DOES LONG TERM TREND AND DISTRIBUTION STATUS RELATE TO EACHOTHER? </h3>
# <h5 id='sec26' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> HOW DO THEY RELATE TO THE LONG TERM STATUS AND STATUS OF CONSERVATION CONCERN FOR LEAST CONCERNING SPECIES? </h5>

# %%
fig = px.scatter(df_least, x = "Distribution Range Size (units of 10,000 sq. km.)", y = "Long-term Trend (%)", facet_col = "Status of Conservation Concern", color = "Long Term Status", trendline="ols", hover_name = "Common Name (India Checklist)", color_discrete_map = {"Strong Decline" : "#FEC20F", "Moderate Decline" : '#F6971F', "Stable" : '#C64B8C', "Uncertain" : "#7554A3", "Moderate Increase" : "#96C93C", "Strong Increase" : "#315A39"})
fig.update_layout(autosize = False, width = 1400, height = 500)
# Out:
# <div>                            <div id="a791d636-be6d-4052-9e27-cfea153d52cb" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a791d636-be6d-4052-9e27-cfea153d52cb")) {                    Plotly.newPlot(                        "a791d636-be6d-4052-9e27-cfea153d52cb",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Long Term Status=Stable<br>Status of Conservation Concern=Low<br>Distribution Range Size (units of 10,000 sq. km.)=%{x}<br>Long-term Trend (%)=%{y}<extra></extra>", "hovertext": ["Lesser Whistling Duck", "Garganey", "Northern Shoveler", "Indian Spot-billed Duck", "Red Spurfowl", "Grey Francolin", "Little Grebe", "Oriental Turtle Dove", "Eurasian Collared Dove", "Spotted Dove", "Laughing Dove", "Asian Emerald Dove", 
# ...

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>🪔 The long term declining species have low long term trends and distribution ranges while the long term increasing species have a high long term trends and distribution ranges. Therefore, green points are towards the top right corner and the yellow points are towards the bottom left corner. For high status of conservation concern, only strongly declining long term species exist. While in the low status of conservation concern, mostly increasing, uncertain or stable long term species exist. In moderate status of conservation concern, no increasing long term species exist. Since they are species of least concern, there are more non declining species. A few examples from the graph above are presented below. </div>

# %% [markdown]
# <h5 style = "font-family: Comic Sans MS;color:black;background-color:#B999FF"> LEAST CONCERN (IUCN STATUS) => Long-term Trend + Distribution Range Size + Long Term Status + Status of Conservation Concern</h5>
# <h5 style='font-family: Comic Sans MS;color:black;background-color:#FF5412;'>HIGH (Status of Conservation Concern)</h5>
#
# ![11-min.jpg](attachment:78c6415d-9c7f-4fc0-87d1-873937eea3dd.jpg)
#
# Pacific Golden Plover
#
# ![19-min.jpg](attachment:d82772b9-4d09-43ac-a8c4-83c36f98028d.jpg)
#
# Great Grey Shrike
#
#
# <h5 style='font-family: Comic Sans MS;color:black;background-color:#019992;'>LOW (Status of Conservation Concern)</h5>
#
# ![23-min.jpg](attachment:a6185cd1-d724-403f-b226-b8e946db3a65.jpg)
#
# Rock Pigeon
#
# ![31-min.jpg](attachment:421ba0e7-ae2b-4f6c-b284-083d5d2ac19e.jpg)
#
# Asian Koel

# %%
a = df[df["Common Name (India Checklist)"] == 'Pacific Golden Plover'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Long Term Status', 'Status of Conservation Concern']]
a = a.append(df[df["Common Name (India Checklist)"] == 'Great Grey Shrike'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Long Term Status', 'Status of Conservation Concern']])
a.style.background_gradient(cmap = 'Wistia')
# Out:
# <style  type="text/css" >
# #T_09892024_9f92_11eb_956c_0242ac130202row0_col2,#T_09892024_9f92_11eb_956c_0242ac130202row1_col3{
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }#T_09892024_9f92_11eb_956c_0242ac130202row0_col3,#T_09892024_9f92_11eb_956c_0242ac130202row1_col2{
#             background-color:  #fc7f00;
#             color:  #000000;
# ...

# %%
a = df[df["Common Name (India Checklist)"] == 'Rock Pigeon'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Long Term Status', 'Status of Conservation Concern']]
a = a.append(df[df["Common Name (India Checklist)"] == 'Asian Koel'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Long Term Status', 'Status of Conservation Concern']])
a.style.background_gradient(cmap = 'Greens')
# Out:
# <style  type="text/css" >
# #T_09c1f228_9f92_11eb_956c_0242ac130202row0_col2,#T_09c1f228_9f92_11eb_956c_0242ac130202row0_col3{
#             background-color:  #00441b;
#             color:  #f1f1f1;
#         }#T_09c1f228_9f92_11eb_956c_0242ac130202row1_col2,#T_09c1f228_9f92_11eb_956c_0242ac130202row1_col3{
#             background-color:  #f7fcf5;
#             color:  #000000;
# ...

# %% [markdown]
# <h5 id='sec27' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> HOW DO THEY RELATE TO THE LONG TERM STATUS AND STATUS OF CONSERVATION CONCERN FOR CONCERNING SPECIES? </h5>

# %%
fig = px.scatter(df_most, x = "Distribution Range Size (units of 10,000 sq. km.)", y = "Long-term Trend (%)", facet_col = "Status of Conservation Concern", color = "Long Term Status", hover_name = "Common Name (India Checklist)", trendline="ols", color_discrete_map = {"Strong Decline" : "#FEC20F", "Moderate Decline" : '#F6971F', "Stable" : '#C64B8C', "Uncertain" : "#7554A3", "Moderate Increase" : "#96C93C", "Strong Increase" : "#315A39"})
fig.update_layout(autosize = False, width = 1400, height = 500)
# Out:
# <div>                            <div id="6d2a043f-78d5-4155-b25a-9b9a92fd4d7c" class="plotly-graph-div" style="height:500px; width:1400px;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6d2a043f-78d5-4155-b25a-9b9a92fd4d7c")) {                    Plotly.newPlot(                        "6d2a043f-78d5-4155-b25a-9b9a92fd4d7c",                        [{"hovertemplate": "<b>%{hovertext}</b><br><br>Long Term Status=Moderate Decline<br>Status of Conservation Concern=Moderate<br>Distribution Range Size (units of 10,000 sq. km.)=%{x}<br>Long-term Trend (%)=%{y}<extra></extra>", "hovertext": ["Common Pochard", "Sarus Crane", "Great Thick-knee", "River Tern", "Bearded Vulture"], "legendgroup": "Moderate Decline", "marker": {"color": "#F6971F", "symbol": "circle"}, "mode": "markers", "name": "Moderate Decline", "ori
# ...

# %% [markdown]
# <div class = 'alert alert-info' style = 'color:black;'>⚡ The long term declining species have low long term trends and distribution ranges while the long term increasing species have a high long term trends and distribution ranges. Therefore, yellow points are towards the bottom left corner. For high status of conservation concern, only declining long term species exist. While in the low status of conservation concern, only uncertain or stable long term species exist. In moderate status of conservation concern, mostly declining long term species exist. Since they are species of concern, there are more declining species. Also, note that even though some species have a low or moderate status of conservation concern, they do not have any long term increasing species. This explains why they are concerning species. A few examples from the graph above are presented below. </div>

# %% [markdown]
# <h4 style = "font-family: Comic Sans MS;color:black;background-color:#B999FF">CONCERN (IUCN STATUS) => Long-term Trend + Distribution Range Size + Long Term Status + Status of Conservation Concern</h4>
# <h5 style='font-family: Comic Sans MS;color:black;background-color:#FF5412;'>HIGH (Status of Conservation Concern)</h5>
#
# ![1-min.jpg](attachment:a2510449-020d-4519-877f-fdc2702c51ee.jpg)
#
# White-rumped Vulture
#
# ![2-min.jpg](attachment:3ec90215-dee4-4670-b00a-2ff3090d0319.jpg)
#
# Indian Vulture
#
#
# <h5 style='font-family: Comic Sans MS;color:black;background-color:#019992;'>LOW (Status of Conservation Concern)</h5>
#
# ![30-min.jpg](attachment:f46f5445-4675-4d7e-a641-d113acd9dd81.jpg)
#
# Wolly-necked Stork
#
# ![33-min.jpg](attachment:7f6900f9-a30e-4a7d-8fd3-2a1d2e351a91.jpg)
#
# Black-tailed Godwit

# %%
a = df[df["Common Name (India Checklist)"] == 'White-rumped Vulture'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Long Term Status', 'Status of Conservation Concern']]
a = a.append(df[df["Common Name (India Checklist)"] == 'Indian Vulture'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Long Term Status', 'Status of Conservation Concern']])
a.style.background_gradient(cmap = 'Wistia')
# Out:
# <style  type="text/css" >
# #T_0ad84df6_9f92_11eb_956c_0242ac130202row0_col2,#T_0ad84df6_9f92_11eb_956c_0242ac130202row0_col3{
#             background-color:  #e4ff7a;
#             color:  #000000;
#         }#T_0ad84df6_9f92_11eb_956c_0242ac130202row1_col2,#T_0ad84df6_9f92_11eb_956c_0242ac130202row1_col3{
#             background-color:  #fc7f00;
#             color:  #000000;
# ...

# %%
a = df[df["Common Name (India Checklist)"] == 'Woolly-necked Stork'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Long Term Status', 'Status of Conservation Concern']]
a = a.append(df[df["Common Name (India Checklist)"] == 'Black-tailed Godwit'][['Common Name (India Checklist)', 'Scientific Name (India Checklist)', 'Long-term Trend (%)', 'Distribution Range Size (units of 10,000 sq. km.)', 'Long Term Status', 'Status of Conservation Concern']])
a.style.background_gradient(cmap = 'cool')
# Out:
# <style  type="text/css" >
# #T_0b0e8ce0_9f92_11eb_956c_0242ac130202row0_col2,#T_0b0e8ce0_9f92_11eb_956c_0242ac130202row0_col3{
#             background-color:  #ff00ff;
#             color:  #f1f1f1;
#         }#T_0b0e8ce0_9f92_11eb_956c_0242ac130202row1_col2,#T_0b0e8ce0_9f92_11eb_956c_0242ac130202row1_col3{
#             background-color:  #00ffff;
#             color:  #000000;
# ...

# %% [markdown]
# <h2 id='sec28' style = "font-family: Comic Sans MS;color:white;background-color:#000000"> CONCLUSION </h2>

# %% [markdown]
# <div class = 'alert alert-success' style = 'color:black;'>❤ There is a pattern in the images of birds that appear throughout the notebook. A few conclusions can be made by just glancing at the notebook that Vultures (White-rumped Vulture, Indian Vulture, and Red-headed Vulture) are of high status of conservation concern. On the other end of the spectrum, species like Rock Pigeon and Asian Koel are of low status of conservation concern. All species that have IUCN status as low concern don't mean that they are not in danger. A good example is the Pacific Golden Plover. Its IUCN status is low concern but is of high status of conservation concern. Another example is the Woolly-necked Stork, its IUCN status is vulnerable and has a negative long term trend and current annual change. Nevertheless, it is of low status of conservation concern as it has a very large distribution status. Note that all these estimates are of high certainity. </div>

# %% [markdown]
# <h3 style = 'font-family: Comic Sans MS;background-color:#FFD3B5;color:black;'> PLEASE UPVOTE AND SHARE IF YOU FOUND ANYTHING HELPFUL. THANK YOU IN ADVANCE! </h3>
#
# ![1200px-Facebook_Thumb_icon.svg-min.png](attachment:6c9e9606-a512-4263-ade5-3760ef39aebc.png)
